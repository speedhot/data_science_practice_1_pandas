# %%
import pandas as pd
print(dir(pd))
# Out:
# ['Categorical', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'ExcelFile', 'ExcelWriter', 'Expr', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int64Index', 'Interval', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Period', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseSeries', 'Term', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt64Index', 'WidePanel', '_DeprecatedModule', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p10', '_np_version_under1p11', '_np_version_under1p12', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_tslib', '_version', 'api', 'bdate_range', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'datetime', 'datetools', 'describe_option', 'errors', 'eval', 'factorize', 'get_dummies', 'get_o
# ...

# %% [markdown]
# ### Reading & Writing files
# #### 1. read_csv(.csv

# %%
import pandas as pd
df = pd.read_csv('./data/test.csv')    # Supply the file name (path)

#draft1.head(6)                           # Check the first 6 rows

df.head() ##df.head()  # default value is 5

# draft1.iloc[10:20, 0:5]


#df   #-------- for whole file   # it will display the complete data frame or full file
#df.iloc[10:20, 0:5] #special rows and columns [10:20] rows from 10 to 19 and [0:5] columns from 0 to 4
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# #### 2. read_table(.tsv)

# %%
# TSV: tab-delimited file (Its a subset of csv file)

# Excel > CSV > TSV

'''
TSV is a file extension for a tab-delimited file used with spreadsheet software. 
TSV stands for Tab Separated Values. TSV files are used for raw data and can be imported into and exported from 
spreadsheet software. 

Diff btwn csv & tsv:
In some enterprise environments TSV is so prevalent that its bulk usage in those cases that it makes it very difficult
to judge. For instance, the default text format used in Hadoop is tab delimited files, 
using CSV is much more complicated. 
Given that the petabytes of data that has been stored in this format, 
I think it is likely that there is more data in the world stored in TSV, 
but that there are more CSV files in existance.
'''

df2 = pd.read_table('./data/test.tsv')  # Read a tsv into a DataFrame
df2.head(6)                           # Check the first 6 rows
df2.iloc[0:2, 0:5]   # for specific rows and columns
# Out:
#     x    y    z
# 0   5   90  110
# 1  25   30  200

# %% [markdown]
# ### 3. read_excel(.xlsx)

# %%
df3 = pd.read_excel('./data/test.xlsx')       # Path to Excel file
# draft3 = pd.read_excel('test.xlsx', sheetname = 'sheet1') # Name of sheet to read from

df3.head(6)                            # Check the first 6 rows
# Out:
#       Category    Function                                        Description  \
# 0      Logical     IFERROR  Returns a different result if the first argume...
# 1  Statistical   AVERAGEIF  Returns the average for the cells specified by...
# 2  Statistical  AVERAGEIFS  Returns the average for the cells specified by...
# 3  Statistical    COUNTIFS  Counts the number of cells that meet multiple ...
# 4  Math & Trig      SUMIFS    Adds the cells specified by a multiple criteria
# 5         Cube  CUBEMEMBER      Returns a member or tuple in a cube hierarchy
#
#    New?  Help Topic         Help
# 0  True  HA01231765  <More Info>
# 1  True  HA10047433  <More Info>
# 2  True  HA10047493  <More Info>
# 3  True  HA10047494  <More Info>
# 4  True  HA10047504  <More Info>
# 5  True  HA10083017  <More Info>

# %% [markdown]
# ### 4. read_html(.html from url)

# %%
# url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
#url = "https://www.w3schools.com/bootstrap/bootstrap_tables.asp"
url="https://www.ksvira.edu.in/vira_bijnor_up_india_rule_regulation.php#proctorialboard"
# it will extract all tables from url
BB_data = pd.read_html(url)         # Read data from the specified url
print(BB_data)

BB_data[0].iloc[:, 0:10].head(5)      # Check 5 rows (10 columns only)
# Out:
# [              0   1
# 0  Enquiry Form NaN
# 1          Name NaN
# 2      Email ID NaN
# 3    Mobile No. NaN
# 4       Address NaN
# 5         Query NaN
# 6           NaN NaN,                                0                             1            2  \
# 0  Grievance Redressal Committee                           NaN          NaN
# 1                          S.No.  NAME OF THE COMMITTEE MEMBER  DESIGNATION
# 2                              1      Prof.(Dr.) SHAMIM AKHTAR         Head
# 3                              2              Mr. AJAY VISHNOI       Member
# 4                              3             Ms. NIDHI BISHNOI       Member
# 5                              4            Mr. LOKESH AGRAWAL       Member
# 6                              5               Mr. ANKIT RAJAN       Member
# 7                              6           Mr. ROHIT CHAUDHARY       Member
# 8                              7              Mr. GOURAV GUPTA       Member
# ...

# %% [markdown]
# ### 5. read_clipboard

# %%
df4=pd.read_clipboard(sep=',')  #what have you copied it will print that
print(df4)
# Out:
#    0  Default Defaultson  def@somemail.com
# 0  1  Success        Doe  john@example.com
# 1  2   Danger        Moe  mary@example.com
# 2  3     Info     Dooley  july@example.com
# 3  4  Warning       Refs    bo@example.com

# %% [markdown]
# ## Save Data

# %%
# it save the last loaded data frame to given destination
df4.to_csv("./data/save.csv")    #it would create the file if not exist 

#we can check the list directory if created
import os
os.listdir(os.getcwd()) #list the current working directory 
os.listdir('./data')   # list the files on a given path
# Out:
# ['bb_data.csv',
#  'Icon_',
#  'save.csv',
#  'test.csv',
#  'test.html',
#  'test.tsv',
#  'test.xlsx',
#  'titanic.csv']

# %% [markdown]
# ## Playing with data set

# %% [markdown]
# #### 1. Playing with Titanic data set

# %%
import numpy as np
import pandas as pd
#import os
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_titanic=pd.read_csv("./data/train.csv")
df_titanic.head(20)  #to print head of data first 5 rows by default
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_titanic.shape #to print complete shape (row, columns)
# Out:
# (891, 12)

# %%
#to print columns data type
df_titanic.dtypes     #it is .types due to haterogeneous data
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_titanic.describe() # to show basic statics over the data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# For categorical(object) dtypes -----data other than numerical types(typewise categories)

categorical = df_titanic.dtypes[df_titanic.dtypes == "object"].index #.index is used to extract all the columns headers
print(categorical)
#describe this data ---means basic stats
df_titanic[categorical].describe()
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
#                                Name   Sex  Ticket Cabin Embarked
# count                           891   891     891   204      889
# unique                          891     2     681   147        3
# top     Lundahl, Mr. Johan Svensson  male  347082    G6        S
# freq                              1   577       7     4      644

# %%
#if we want to retrive particular column header
print(categorical[0])   #it will return first column header
# Out:
# Name

# %%
# can do basic statics on the individual columns
df_titanic[categorical[0]].describe()
# Out:
# count                             891
# unique                            891
# top       Lundahl, Mr. Johan Svensson
# freq                                1
# Name: Name, dtype: object

# %%
sorted(df_titanic["Name"])[0:15]  # Check the first 15 sorted names
# Out:
# ['Abbing, Mr. Anthony',
#  'Abbott, Mr. Rossmore Edward',
#  'Abbott, Mrs. Stanton (Rosa Hunt)',
#  'Abelson, Mr. Samuel',
#  'Abelson, Mrs. Samuel (Hannah Wizosky)',
#  'Adahl, Mr. Mauritz Nils Martin',
#  'Adams, Mr. John',
#  'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Aks, Mrs. Sam (Leah Rosen)',
#  'Albimona, Mr. Nassef Cassem',
#  'Alexander, Mr. William',
#  'Alhomaki, Mr. Ilmari Rudolf',
#  'Ali, Mr. Ahmed',
#  'Ali, Mr. William',
#  'Allen, Miss. Elisabeth Walton']

# %%
#can describe individual column's name
df_titanic["Name"].describe()
# Out:
# count                             891
# unique                            891
# top       Lundahl, Mr. Johan Svensson
# freq                                1
# Name: Name, dtype: object

# %% [markdown]
# ### 1. Analysis of survived columns according to category(survived, died)

# %%
#categorised  the survived or not survived in two columns
#step 1. first load the surviverd columns in new series new_survived

new_survived=pd.Categorical(df_titanic["Survived"])
print(new_survived)

# step 2. Devide the survived category in two Died and Survived
new_survived_category = new_survived.rename_categories(["Died","Survived"])  
print(new_survive_category)

#step 3. stdescribe the new_survive_category ---and print how many survived and died
new_survived_category.describe()
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]
# [Died, Survived, Survived, Survived, Died, ..., Died, Survived, Died, Survived, Died]
# Length: 891
# Categories (2, object): [Died, Survived]
#             counts     freqs
# categories
# Died           549  0.616162
# Survived       342  0.383838

# %% [markdown]
# ### 2.Analysis of Pclass columns according to category(first, second,third)class

# %%
# apply the same steps to similarly describe the class column

#now start the procedure to--- load it into single series of classes
new_Pclass=pd.Categorical(df_titanic["Pclass"], ordered=True)   # extra parameter ordered=True to show the category priority
#print the category series of Passenger's class
print(new_Pclass)   # it is showing total categories of passenger's class is 3, 
# devide them in three
new_3_classes=new_Pclass.rename_categories(["First","Second","Third"])
#print the pclass column with renamed three classes
print(new_3_classes)

#describe the stats of passengers classes
new_3_classes.describe()
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1 < 2 < 3]
# [Third, First, Third, First, Third, ..., Second, First, Third, First, Third]
# Length: 891
# Categories (3, object): [First < Second < Third]
#             counts     freqs
# categories
# First          216  0.242424
# Second         184  0.206510
# Third          491  0.551066

# %% [markdown]
# ### 3.Analysis of sex column according to category(male, female)

# %%
new_sex=pd.Categorical(df_titanic["Sex"])
print(new_sex)   #shows already devided into categories no need of renaming
new_sex.describe()
# Out:
# [male, female, female, female, male, ..., male, female, female, male, male]
# Length: 891
# Categories (2, object): [female, male]
#             counts     freqs
# categories
# female         314  0.352413
# male           577  0.647587

# %% [markdown]
# ## Udating new categories in to the data frame

# %%
#if instead of Pclass(1,2,3) we want (first,second,third) in the column we can do like
df_titanic["Pclass"]=new_3_classes
df_titanic["Survived"]=new_survive_category   
df_titanic.head()


#Note : also showing the mutability of DataFrame 
#note: changes are not in harddisk file only in DataFrame
# Out:
#    PassengerId  Survived Pclass  \
# 0            1      Died  Third
# 1            2  Survived  First
# 2            3  Survived  Third
# 3            4  Survived  First
# 4            5      Died  Third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Some more df function

# %%
# del keyword

# Remove PassengerId (will be removed from df not from the actual data source)
#del df_titanic["Pclass"]  
df_titanic.head() # there is no Pclass column in DataFrame now
# Out:
#    Survived                                               Name     Sex   Age  \
# 0      Died                            Braund, Mr. Owen Harris    male  22.0
# 1  Survived  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  Survived                             Heikkinen, Miss. Laina  female  26.0
# 3  Survived       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4      Died                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
# reloading data
df_titanic = pd.read_csv("./data/train.csv")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# unique()

df_titanic["Cabin"].unique()   # provide unique cabins

# dtype for cabin is "object"
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#coverting data type-----------using astype(str)
#convert cabin data type from object to string
import numpy as np
# read all cabin as string
char_cabin = df_titanic["Cabin"].astype(str) 
print(char_cabin.unique(),"\n\n")
print(char_cabin.head(),"\n\n")


# Take first letter & create np array
new_Cabin = np.array([cabin[0] for cabin in char_cabin]) 
print(new_Cabin,"\n\n")

## create Categorical object
new_Cabin = pd.Categorical(new_Cabin)
print(new_Cabin,"\n\n")
new_Cabin.describe()
# Out:
# ['nan' 'C85' 'C123' 'E46' 'G6' 'C103' 'D56' 'A6' 'C23 C25 C27' 'B78' 'D33'
#  'B30' 'C52' 'B28' 'C83' 'F33' 'F G73' 'E31' 'A5' 'D10 D12' 'D26' 'C110'
#  'B58 B60' 'E101' 'F E69' 'D47' 'B86' 'F2' 'C2' 'E33' 'B19' 'A7' 'C49'
#  'F4' 'A32' 'B4' 'B80' 'A31' 'D36' 'D15' 'C93' 'C78' 'D35' 'C87' 'B77'
#  'E67' 'B94' 'C125' 'C99' 'C118' 'D7' 'A19' 'B49' 'D' 'C22 C26' 'C106'
#  'C65' 'E36' 'C54' 'B57 B59 B63 B66' 'C7' 'E34' 'C32' 'B18' 'C124' 'C91'
#  'E40' 'T' 'C128' 'D37' 'B35' 'E50' 'C82' 'B96 B98' 'E10' 'E44' 'A34'
#  'C104' 'C111' 'C92' 'E38' 'D21' 'E12' 'E63' 'A14' 'B37' 'C30' 'D20' 'B79'
#  'E25' 'D46' 'B73' 'C95' 'B38' 'B39' 'B22' 'C86' 'C70' 'A16' 'C101' 'C68'
#  'A10' 'E68' 'B41' 'A20' 'D19' 'D50' 'D9' 'A23' 'B50' 'A26' 'D48' 'E58'
#  'C126' 'B71' 'B51 B53 B55' 'D49' 'B5' 'B20' 'F G63' 'C62 C64' 'E24' 'C90'
#  'C45' 'E8' 'B101' 'D45' 'C46' 'D30' 'E121' 'D11' 'E77' 'F38' 'B3' 'D6'
#  'B82 B84' 'D17' 'A36' 'B102' 'B69' 'E49' 'C47' 'D28' 'E17' 'A24' 'C50'
#  'B42' 'C148']
#
#
# ...

# %%
df_titanic["Cabin"] = new_Cabin
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     n        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     n        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     n        S

# %% [markdown]
# ## Series

# %% [markdown]
# Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index.
#
# **pandas.Series**
#
# pandas.Series( data, index, dtype, copy)
#
# **data: data takes various forms like ndarray, list, constants
#
# **index: Index values must be unique and hashable, same length as data. Default np.arrange(n) if no index is passed.
#
# **dtype: dtype is for data type. If None, data type will be inferred
#
# **copy: Copy data. Default False

# %%
#creating different types of data
import numpy as np
import pandas as pd

labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)

d = {'a':10,'b':20,'c':30}

print ("Labels:", labels)
print("My data:", my_data)
#print(arr)
print("Dictionary:", d)
# Out:
# Labels: ['a', 'b', 'c']
# My data: [10, 20, 30]
# Dictionary: {'a': 10, 'b': 20, 'c': 30}

# %%
#creating series with data only from list
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data, index=labels, dtype=float) #with label and dtype parameter
# Out:
# a    10.0
# b    20.0
# c    30.0
# dtype: float64

# %%
#series from numpy array
print ("\nHolding numerical data\n",'-'*25, sep='')
print(pd.Series(arr))
# Out:
# Holding numerical data
# -------------------------
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
#series can be of functions also
print ("\nHolding functions\n",'-'*20, sep='')
print(pd.Series(data=[sum,print,len]))
# Out:
# Holding functions
# --------------------
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
#series of a dictionary
pd.Series(d)   #d is above created dictionary here
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print ("\nHolding objects from a dictionary\n",'-'*40, sep='')
s = pd.Series(data=[d.keys, d.items, d.values])
# print(pd.Series(data=[d.keys, d.items, d.values]))
s[0]
# Out:
# Holding objects from a dictionary
# ----------------------------------------
# <function dict.keys>

# %% [markdown]
# ## Some operations over the series

# %%
# Access Series elements

ser1 = pd.Series([1,2,3,4],['CA', 'OR', 'CO', 'AZ'])

# access by lable
print(ser1['CO'])

#access by index
print(ser1[2],"\n\n")

# access range
print(ser1[1:4])
# Out:
# 3
# 3
#
#
# OR    2
# CO    3
# AZ    4
# dtype: int64

# %%
# Arithmetic operations on Series
#Python tries to add values where it finds common index name, and puts NaN where indices are missing

ser1 = pd.Series([1,2,3,4],['CA', 'OR', 'CO', 'AZ'])
ser2 = pd.Series([1,2,5,4],['CA', 'OR', 'VN', 'AZ'])

print(ser1+ser2,"\n\n")
print(ser1*ser2,"\n\n")
print(ser1/ser2,"\n\n")

# combination of mathematical operations!
print(np.exp(ser1)+np.log10(ser2))
# Out:
# AZ    8.0
# CA    2.0
# CO    NaN
# OR    4.0
# VN    NaN
# dtype: float64
#
#
# AZ    16.0
# CA     1.0
# CO     NaN
# OR     4.0
# VN     NaN
# dtype: float64
#
#
# AZ    1.0
# CA    1.0
# CO    NaN
# OR    1.0
# VN    NaN
# dtype: float64
#
#
# AZ    55.200210
# CA     2.718282
# CO          NaN
# OR     7.690086
# VN          NaN
# dtype: float64

# %%
# using where()-- Max

index = np.where(df_titanic["Fare"] == max(df_titanic["Fare"]) )
print(index)
df_titanic.iloc[index]
# Out:
# (array([258, 679, 737], dtype=int64),)
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
# Combind 2 column and create new column
# new column will be added at the end

df_titanic["Family"] = df_titanic["SibSp"] + df_titanic["Parch"]

most_family = np.where(df_titanic["Family"] == max(df_titanic["Family"]))


#del df_titanic["SibSp"]
df_titanic.iloc[most_family]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SibSp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-60a9558f3d33> in <module>()
# ...

# %% [markdown]
# ### check for null values

# %%
#practical example
import pandas as pd
dummy_vector = pd.Series([1,None,3,None,7,8])
print(dummy_vector)
print(dummy_vector.isnull())
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# 3    NaN
# 4    7.0
# 5    8.0
# dtype: float64
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
# Identifying missing age in titanic dataframe
new_age=df_titanic["Age"]

final_age=df_titanic[new_age.isnull()==False]
missing_age=df_titanic[new_age.isnull()==True]
print("Data Frame with missing age",missing_age)
print("Data Frame without missing age",final_age)
# Out:
# Data Frame with missing age      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
# Identifying missing age in titanic dataframe------ in single column

final_age=np.where(df_titanic["Age"].isnull()==False)
missing_age=np.where(df_titanic["Age"].isnull()==True)
print("Data Frame with missing age",missing_age)
print("Data Frame without missing age",final_age)
# Out:
# Data Frame with missing age (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#         48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#        126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#        196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#        270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#        334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#        409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#        459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#        511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#        564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#        613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#        692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#        773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
#removing of missing age rows from data frame
new_df=df_titanic[df_titanic["Age"].isnull()==False]
new_df.head(10)
#len(new_df)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ### Data Frames
# Data Frames
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# Features of DataFrame
#
# Potentially columns are of different types
#
# Size – Mutable
# Labeled axes (rows and columns)
# Can Perform Arithmetic operations on rows and columns
# pandas.DataFrame
#
# **pandas.DataFrame( data, index, columns, dtype, copy)**
#
# Parameter & Description
# data: data takes various forms like ndarray, series, map, lists, dict, constants and also another DataFrame.
# index: For the row labels, the Index to be used for the resulting frame is Optional Default np.arrange(n) if no index is passed.
# columns: For column labels, the optional default syntax is - np.arrange(n). This is only true if no index is passed.
# dtype: Data type of each column.
# copy: This command (or whatever it is) is used for copying of data, if the default is False.
# Create DataFrame
#
# A pandas DataFrame can be created using various inputs like
#
# Lists
#
# dict
#
# Series
#
# Numpy ndarrays
#
# Another DataFrame

# %%
# Create DF

from numpy.random import randn as rn
# np.random.seed(100)   # if we want same random number every in every execution than pass through seed()

matrix_data = rn(5,4)
# print(matrix_data)

row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']

df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings) # creating Data Frame
print("\nThe data frame looks like\n",'-'*45, sep='')
print(df)
# Out:
# The data frame looks like
# ---------------------------------------------
#           W         X         Y         Z
# A  0.908289  2.012603  1.152606  0.455408
# B -0.658325  2.577025  0.653872 -0.701613
# C -1.731981 -0.052467 -1.080530 -0.289303
# D -0.882668 -0.599362  0.331251 -0.236479
# E -0.177817  0.265841 -0.041511 -0.555195

# %%
# Access Column 
## df.X (NOT RECOMMENDED)
## df[col_name]

print("\nThe 'X' and 'Z' columns indexed by passing a list\n",'-'*55, sep='')
print(df[['X','Z']])

#col type
print("\nType of the column: ", type(df['X']), sep='')

# for more than one column, the object turns into a DataFrame
print("\nType of the pair of columns: ", type(df[['X','Z']]), sep='')
df
# Out:
# The 'X' and 'Z' columns indexed by passing a list
# -------------------------------------------------------
#           X         Z
# A  0.724793 -1.707045
# B  0.931525  0.200585
# C  0.921044 -0.148514
# D -1.101341 -0.613786
# E -0.660590 -2.461910
#
# Type of the column: <class 'pandas.core.series.Series'>
#
# Type of the pair of columns: <class 'pandas.core.frame.DataFrame'>
#           W         X         Y         Z
# A -1.988540  0.724793 -0.125217 -1.707045
# B  1.361845  0.931525  1.240722  0.200585
# C -0.371806  0.921044  0.615419 -0.148514
# D  1.865012 -1.101341 -0.775541 -0.613786
# E -0.028064 -0.660590 -0.057080 -2.461910

# %%
# drop column
#del df[colname]

print("\nA column is dropped by using df.drop() method\n",'-'*55, sep='')
df = df.drop('W', axis=1) # Notice the axis=1 option, axis = 0 is default, so one has to change it to 1
df
# Out:
# A column is dropped by using df.drop() method
# -------------------------------------------------------
#           X         Y         Z
# A  0.724793 -0.125217 -1.707045
# B  0.931525  1.240722  0.200585
# C  0.921044  0.615419 -0.148514
# D -1.101341 -0.775541 -0.613786
# E -0.660590 -0.057080 -2.461910

# %%
# df1=df.drop('A')
df1=df.drop('A', axis = 0)
print("\nA row (index) is dropped by using df.drop() method and axis=0\n",'-'*65, sep='')
print(df1)
# Out:
# A row (index) is dropped by using df.drop() method and axis=0
# -----------------------------------------------------------------
#           W         X         Y         Z
# B  0.460878 -0.798675 -0.298257  0.241594
# C  1.322850 -1.030584  1.835907 -0.639517
# D -2.477373  0.257720  1.063910 -0.931198
# E  0.255760  0.163025  0.922636  0.564932

# %% [markdown]
# ### Selecting/indexing Rows
# **Label-based 'loc' method**
#
# **Index (numeric) 'iloc' method**

# %%
print(df)
print("\nLabel-based 'loc' method can be used for selecting row(s)\n",'-'*60, sep='')

print("\nSingle row\n")
#df[colname]
print(df.loc['C'],"\n") #for rows
print(df.iloc[2])
print('-'*60, sep='')

print("\nMultiple rows\n")
print(df.loc[['B','C']],"\n")
print(df.iloc[[1,2]])
# Out:
#           W         X         Y         Z
# A  0.908289  2.012603  1.152606  0.455408
# B -0.658325  2.577025  0.653872 -0.701613
# C -1.731981 -0.052467 -1.080530 -0.289303
# D -0.882668 -0.599362  0.331251 -0.236479
# E -0.177817  0.265841 -0.041511 -0.555195
#
# Label-based 'loc' method can be used for selecting row(s)
# ------------------------------------------------------------
#
# Single row
#
# W   -1.731981
# X   -0.052467
# Y   -1.080530
# Z   -0.289303
# Name: C, dtype: float64
#
# W   -1.731981
# X   -0.052467
# Y   -1.080530
# Z   -0.289303
# Name: C, dtype: float64
# ------------------------------------------------------------
#
# Multiple rows
#
#           W         X         Y         Z
# B -0.658325  2.577025  0.653872 -0.701613
# C -1.731981 -0.052467 -1.080530 -0.289303
#
#           W         X         Y         Z
# B -0.658325  2.577025  0.653872 -0.701613
# C -1.731981 -0.052467 -1.080530 -0.289303

# %% [markdown]
# ### Subsetting DataFrame

# %%
matrix_data = rn(5,4)
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']
df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
df
# Out:
#           W         X         Y         Z
# A -0.106091 -0.016822 -0.908834 -0.960817
# B -0.133980 -0.866749 -0.400978  1.581843
# C  0.655162 -0.584902 -0.569367  0.988483
# D -0.100099 -1.125134  0.501887 -0.397169
# E  0.857857  0.417559 -1.344643 -1.260697

# %%
print("\nElement at row 'B' and column 'Y' is") 
print(df.loc['B','Y'])    #row and column subsetting with single[] rather than[[]]
print(df.iloc[1,2])

# fetch sub dataframe
print("\nSubset comprising of rows B and D, and columns W and Y, is")
print(df.loc[ ['B','D'], ['W','Y'] ])
# Out:
# Element at row 'B' and column 'Y' is
# -0.4009783529834052
# -0.4009783529834052
#
# Subset comprising of rows B and D, and columns W and Y, is
#           W         Y
# B -0.133980 -0.400978
# D -0.100099  0.501887

# %%
# Boolean DataFrame(s)

print(df,"\n\n")
booldf = df>0
print(booldf,"\n\n")

print("\nDataFrame indexed by boolean dataframe\n",'-'*45, sep='')
print(df[booldf])


# print(df,"\n\n")
# #booldf = df>0
# lam = lambda a: df>0 
# print(lam,"\n\n")

# print("\nDataFrame indexed by boolean dataframe\n",'-'*45, sep='')
# print(df[lam])
# Out:
#           W         X         Y         Z
# A -0.106091 -0.016822 -0.908834 -0.960817
# B -0.133980 -0.866749 -0.400978  1.581843
# C  0.655162 -0.584902 -0.569367  0.988483
# D -0.100099 -1.125134  0.501887 -0.397169
# E  0.857857  0.417559 -1.344643 -1.260697
#
#
#        W      X      Y      Z
# A  False  False  False  False
# B  False  False  False   True
# C   True  False  False   True
# D  False  False   True  False
# E   True   True  False  False
#
#
#
# DataFrame indexed by boolean dataframe
# ---------------------------------------------
#           W         X         Y         Z
# A       NaN       NaN       NaN       NaN
# B       NaN       NaN       NaN  1.581843
# C  0.655162       NaN       NaN  0.988483
# D       NaN       NaN  0.501887       NaN
# E  0.857857  0.417559       NaN       NaN

# %%
print("\nRows with W > 0.2\n",'-'*35, sep='')
print(df[ df['W']>0.2    ])


# print("\nRows with W > 0.2\n",'-'*35, sep='')
# col = df['W']>0.2
# print(col)
# lst = df[ col ]
# print(lst)
# Out:
# Rows with W > 0.2
# -----------------------------------
#           W         X         Y         Z
# C  0.655162 -0.584902 -0.569367  0.988483
# E  0.857857  0.417559 -1.344643 -1.260697

# %% [markdown]
# ### Multi-indexing ( Hierarchical indexing )
# The MultiIndex object is the hierarchical analogue of the standard Index object which typically stores the axis labels in pandas objects. You can think of MultiIndex as an array of tuples where each tuple is unique. A MultiIndex can be created from a list of arrays (using MultiIndex.from_arrays), an array of tuples (using MultiIndex.from_tuples), or a crossed set of iterables (using MultiIndex.from_product). The Index constructor will attempt to return a MultiIndex when it is passed a list of tuples.

# %%
# Index Levels

outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))

print("\nTuple pairs after the zip and list command\n",'-'*45, sep='')
print(hier_index)


#or
print("\n Unsing zip() Mannually by for loop\n","_"*50)
for item in zip(outside,inside):
    print(item)
# Out:
# Tuple pairs after the zip and list command
# ---------------------------------------------
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]
#
#  Unsing zip() Mannually by for loop
#  __________________________________________________
# ('G1', 1)
# ('G1', 2)
# ('G1', 3)
# ('G2', 1)
# ('G2', 2)
# ('G2', 3)

# %%
# creating Multi-Index using pandas->MultiIndex.from_tuples

hier_index = pd.MultiIndex.from_tuples(hier_index)
print("\nIndex hierarchy\n",'-'*25, sep='')
print(hier_index,"\n\n")
print(type(hier_index))
# Out:
# Index hierarchy
# -------------------------
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])
#
#
# <class 'pandas.core.indexes.multi.MultiIndex'>

# %%
print("\nCreating DataFrame with multi-index\n",'-'*37, sep='')

data=np.random.randint(1,10,(6,3))
# data=np.random.randint(1,10,(5,3)) #it will through error

print(data,"\n\n")
df1 = pd.DataFrame(data, index= hier_index, columns= ['A','B','C'])
print(df1)
# Out:
# Creating DataFrame with multi-index
# -------------------------------------
# [[9 4 3]
#  [1 9 1]
#  [8 8 6]
#  [4 6 7]
#  [8 8 5]
#  [6 4 8]]
#
#
#       A  B  C
# G1 1  9  4  3
#    2  1  9  1
#    3  8  8  6
# G2 1  4  6  7
#    2  8  8  5
#    3  6  4  8

# %%
print("\nNaming the indices by 'index.names' method\n",'-'*45, sep='')
df1.index.names=['Outer', 'Inner']
print(df1)
# Out:
# Naming the indices by 'index.names' method
# ---------------------------------------------
#              A  B  C
# Outer Inner
# G1    1      9  4  3
#       2      1  9  1
#       3      8  8  6
# G2    1      4  6  7
#       2      8  8  5
#       3      6  4  8

# %%
#cross tabulation like pivot table
print("\nGrabbing a cross-section from outer level\n",'-'*45, sep='')
print(df1.xs('G1'))
# Out:
# Grabbing a cross-section from outer level
# ---------------------------------------------
#        A  B  C
# Inner
# 1      9  4  3
# 2      1  9  1
# 3      8  8  6

# %%
print("\nGrabbing a cross-section from inner level (for all outer levels)\n",'-'*65, sep='')
print(df1.xs(2,level='Inner'))
# Out:
# Grabbing a cross-section from inner level (for all outer levels)
# -----------------------------------------------------------------
#        A  B  C
# Outer
# G1     1  9  1
# G2     8  8  5

# %% [markdown]
# # TODO

# %%
#Q1. "Read .tsv" url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
import pandas as pd
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df=pd.read_table(url, sep="\t")
df.head()
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
#print first 5 and last 7 records iloc[rows, columns]
df1=df.iloc[0:5]
df2=df.iloc[-7:]   # or df.tail(7)

print(df1)
print(df2)
# df_result=pd.concat(df1,df2)
# df_result=df_result.reset_index(drop=True)
# df_result
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# ...

# %%
# print total records and type of variables 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
df.shape
#df.shape[0]
# Out:
# (4622, 5)

# %%
##Q:Print the name of all the columns.

#df.index
print(df.columns)

#mannaul
Columns = df.dtypes.index #.index is used to extract all the columns headers
print("column Indexes or Names\n","_"*30,"\n",Columns)

#print index categories
cate1=df.dtypes[df.dtypes=="object"].index
print("Columns having dtype=object:\n",cate1)


#print index with rather than object
cate2=df.dtypes[df.dtypes!="object"].index
print("Columns having dtype!=object:\n",cate2)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')
# column Indexes or Names
#  ______________________________
#  Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')
# Columns having dtype=object:
#  Index(['item_name', 'choice_description', 'item_price'], dtype='object')
# Columns having dtype!=object:
#  Index(['order_id', 'quantity'], dtype='object')

# %%
#How is the dataset indexed?
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#Which was the most ordered item? and How many items were ordered?
c= df.groupby('item_name')

c = c.sum()
#print(c)
c = c.sort_values(['quantity'], ascending=False)
print(c.head(1))
print(c.head(1)['quantity'])
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
#What was the most ordered item in the choice_description column?

m_item=df.groupby('choice_description').sum()
m_item=m_item.sort_values(['quantity'], ascending=False)
m_item.head(1)['quantity']
# Out:
# choice_description
# [Diet Coke]    159
# Name: quantity, dtype: int64

# %%
#Q:#Turn the item price into a float

#mannual using list
new_price=[df['item_price']]
new_float_price=[]
print(type(new_price))
for item in new_price:
       for i in item:
            new_float_price.append(i[1:])
new_price_array=np.array(new_float_price, dtype=float)
df['item_price']=new_price_array
df.head()
# Out:
# <class 'list'>
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['item_price'].dtypes
# Out:
# dtype('float64')

# %%
#sortcut mathod using lambda function
dollar = lambda x: float(x[1:-1])
df.item_price = df.item_price.apply(dollar)   # we can apply lambda like this also using apply function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-e0168f38612e> in <module>()
#       1 #sortcut mathod using lambda function
#       2 dollar = lambda x: float(x[1:-1])
# ----> 3 df.item_price = df.item_price.apply(dollar)   # we can apply lambda like this also using apply function
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-187-e0168f38612e> in <lambda>(x)
#       1 #sortcut mathod using lambda function
# ----> 2 dollar = lambda x: float(x[1:-1])
# ...

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
#Q#How much was the revenue for the period in the dataset?

revenue = (df['quantity']* df['item_price']).sum()
print(revenue)
#in $
print("Toatal revenue= $"+str(np.round(revenue,1)))
# Out:
# 39237.02
# Toatal revenue= $39237.0

# %%
#print a data frame with only two columns item_name and item_price
#solution mannual
df2=df.iloc[:, 2:5]
df2.head()
del df2['choice_description']
df2
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 9                             Steak Burrito        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 13                             Chicken Bowl       11.25
# 14                      Chips and Guacamole        4.45
# 15    Chips and Tomatillo-Green Chili Salsa        2.39
# ...

# %% [markdown]
# ### unit price of the product---------calculation

# %%
#find unique items
unique_items=df.drop_duplicates(['item_name'])
print(unique_items)
print("Total Unique Items=",len(unique_items))
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 18           9         2                            Canned Soda
# 21          11         1                       Barbacoa Burrito
# ...

# %%
#need to be disscuss
# delete the duplicates in item_name and quantity

filtered = df.drop_duplicates(['item_name','quantity'])

# select only the products with quantity equals to 1
one_prod = filtered[filtered.quantity == 1]

# select only the item_name and item_price columns
price_per_item = one_prod[['item_name', 'item_price']]

# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %% [markdown]
# ### What was the quantity of the most expensive item ordered?

# %%
df.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### How many times were a Veggie Salad Bowl ordered?

# %%
print(df[df.item_name == "Veggie Salad Bowl"])
#print(len(df[df.item_name == "Veggie Salad Bowl"]))
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...
